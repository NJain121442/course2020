# %% [markdown]
# <a href="https://colab.research.google.com/github/NJain121442/course2020/blob/master/Fruits_unsupervised_clustering_conv2_5August_SEM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch.nn as nn
import glob
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn.functional as F
import torch.optim as optim
from IPython.display import clear_output
from torchvision import datasets, transforms
import numpy as np
from torchsummary import summary 
import matplotlib.image as mpimg
import torchvision

# %%
#from google.colab import drive 
#drive.mount("/content/drive")

# %%
#!unzip '/content/drive/My Drive/AutoEncoder_training.zip' -d '/content/drive/My Drive/AutoEncoder_training'

# %%
#!unzip /content/Fruits.zip -d /content/

# %%
#Data_path = "/content/Fruits/"
Data_path = "/content/drive/My Drive/AutoEncoder_training/AutoEncoder_training/"

# %%
#filelist = glob.glob(Data_path+'/*.jfif')
filelist = glob.glob(Data_path+'/*.tiff')

# %%
filelist[2]
# Out:
# '/content/drive/My Drive/AutoEncoder_training/AutoEncoder_training/Defect_11285_Class_1_Multi.tiff'

# %%
len(filelist)
# Out:
# 90

# %%
from PIL import Image

Image.open(filelist[88])
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=504x504 at 0x7F473632BCC0>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread(filelist[88])
print(img.shape)
plt.imshow(img)
# Out:
# (504, 504)

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread(filelist[9])
print('Original Dimensions : ',img.shape)
cv2_imshow(img)
dim = (504,504)
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
print('Resized Dimensions : ',resized.shape)
cv2_imshow(resized)
# Out:
# Original Dimensions :  (504, 504, 3)
# <PIL.Image.Image image mode=RGB size=504x504 at 0x7F47362FAB00>
# Resized Dimensions :  (504, 504, 3)
# <PIL.Image.Image image mode=RGB size=504x504 at 0x7F47362FAD68>

# %% [markdown]
# Lets Resize all images to same size

# %%
class CustomDataset(Dataset):
  def __init__(self,path,new_size = 226):
    #self.filelist = glob.glob(path+'/*.jfif')
    self.filelist = glob.glob(path+'/*.tiff')
    self.new_size = new_size

  def __len__(self):
    return len(self.filelist)

  def __getitem__(self, idx):
    temp_filepath = self.filelist[idx]
    temp_image = cv2.imread(temp_filepath)
    #print(temp_image)
    #print('Original Dimensions : ',temp_image.shape)
    #cv2_imshow(temp_image)
    temp_image = cv2.cvtColor(temp_image, cv2.COLOR_BGR2GRAY)
    #print('Original Dimensions : ',temp_image.shape)
    #cv2_imshow(temp_image)
    #dim = (504,504)
    #temp_image = cv2.resize(temp_image, dim, interpolation = cv2.INTER_AREA)
    #print('Resized Dimensions : ',temp_image.shape)
    #cv2_imshow(temp_image)
    #print(temp_image.shape)
    temp_image = temp_image/255
    #plt.imshow(temp_image,cmap='gray',vmin=0,vmax=1)
    #temp_image = torch.from_numpy(temp_image)
    temp_image = torch.Tensor(temp_image)
    #print(temp_image.shape)
    #print(temp_image)
    temp_image = temp_image.unsqueeze(0)
    #print(temp_image.shape)
    return temp_image

# %%
Data = CustomDataset(Data_path)
Data[2].shape
# Out:
# torch.Size([1, 504, 504])

# %%
latent_dim = 1024

class Encoder(nn.Module):
    def __init__(self):
        super(Encoder,self).__init__()
        self.enc1 = nn.Conv2d(1,64,kernel_size=3,stride=3)
        self.enc2 = nn.Conv2d(64,128,kernel_size=3,stride=3)
        self.enc3 = nn.Conv2d(128,256,kernel_size=2,stride=3)
        self.pool = nn.MaxPool2d(2,2,return_indices=True)
        self.FC1 = nn.Linear(6400,latent_dim)
        
    def forward(self,x):
        x = F.relu(self.enc1(x)) # output will be 168x168x64
        x,indices1 = self.pool(x) #output will be 84x84x64
        x = F.relu(self.enc2(x)) #output will be 28x28x128
        x,indices2 = self.pool(x)   # output will be 14x14x128
        x = F.relu(self.enc3(x)) #output will be 5x5x256 
        x = x.view(-1,6400) # after flattening the size will be 6400
        x = F.relu(self.FC1(x)) # the latent space representation
        return x,indices1,indices2
    
class Decoder(nn.Module):
    def __init__(self):
        super(Decoder,self).__init__()
        self.FC2 = nn.Linear(latent_dim,6400)
        self.dec1 = nn.ConvTranspose2d(256,128, kernel_size=2, stride=3)  
        self.dec2 = nn.ConvTranspose2d(128,64, kernel_size=3, stride=3)
        self.dec3 = nn.ConvTranspose2d(64,1, kernel_size=3, stride=3)
        self.unpool = nn.MaxUnpool2d(2,2,padding=0)
        
        
    def forward(self,x,indices1,indices2):
        x = F.relu(self.FC2(x)) #size back to 3200
        x = torch.reshape(x,(1,256,5,5))
        x = F.relu(self.dec1(x)) # ouput will be 14x14x128
        x = self.unpool(x,indices2) #output will be 28x28x128
        x = F.relu(self.dec2(x)) # output will be 84x84x64
        x = self.unpool(x,indices1) #output will be 168x168x64
        #x = self.dec3(x) # output will be 504x504x1
        x = torch.sigmoid(self.dec3(x)) # output will be 504x504x1
        return x
    
class Conv2d_AutoEncoder(nn.Module):
    def __init__(self):
        super(Conv2d_AutoEncoder, self).__init__()

        self.enc = Encoder()
        self.dec = Decoder()

    def forward(self, x):
        
        z,indices1,indices2 = self.enc(x)
        
        out = self.dec(z,indices1,indices2)
        
        return out

# %% [markdown]
# **Lets write the first Auto encoder **

# %%
class Conv2d_Autoencoder(nn.Module):
    def __init__(self):
        super(Conv2d_Autoencoder, self).__init__()
        latent_dim = 1024
 
        # encoder layers
        self.enc1 = nn.Conv2d(1,64,kernel_size=3,stride=3)
        self.enc2 = nn.Conv2d(64,128,kernel_size=3,stride=3)
        self.enc3 = nn.Conv2d(128,256,kernel_size=2,stride=3)
        self.pool = nn.MaxPool2d(2,2,return_indices=True)
        self.FC1 = nn.Linear(6400,latent_dim)
        
        # decoder layers
        self.FC2 = nn.Linear(latent_dim,6400)
        self.dec1 = nn.ConvTranspose2d(256,128, kernel_size=2, stride=3)  
        self.dec2 = nn.ConvTranspose2d(128,64, kernel_size=3, stride=3)
        self.dec3 = nn.ConvTranspose2d(64,1, kernel_size=3, stride=3)
        self.unpool = nn.MaxUnpool2d(2,2,padding=0)

 
    def forward(self, x):
        # encode
        x = F.relu(self.enc1(x)) # output will be 168x168x64
        x,indices1 = self.pool(x) #output will be 84x84x64
        x = F.relu(self.enc2(x)) #output will be 28x28x128
        x,indices2 = self.pool(x)   # output will be 14x14x128
        x = F.relu(self.enc3(x)) #output will be 5x5x256 
        x = x.view(-1,6400) # after flattening the size will be 6400
        x = F.relu(self.FC1(x)) # the latent space representation
  
        # decode
        x = F.relu(self.FC2(x)) #size back to 3200
        x = torch.reshape(x,(1,256,5,5))
        x = F.relu(self.dec1(x)) # ouput will be 14x14x128
        x = self.unpool(x,indices2) #output will be 28x28x128
        x = F.relu(self.dec2(x)) # output will be 84x84x64
        x = self.unpool(x,indices1) #output will be 168x168x64
        #x = self.dec3(x) # output will be 504x504x1
        x = torch.sigmoid(self.dec3(x)) # output will be 504x504x1
        return x

# %%
net = Conv2d_AutoEncoder()
print(net)
#summary(net,(1,504,504))
# Out:
# Conv2d_AutoEncoder(
#   (enc): Encoder(
#     (enc1): Conv2d(1, 64, kernel_size=(3, 3), stride=(3, 3))
#     (enc2): Conv2d(64, 128, kernel_size=(3, 3), stride=(3, 3))
#     (enc3): Conv2d(128, 256, kernel_size=(2, 2), stride=(3, 3))
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (FC1): Linear(in_features=6400, out_features=1024, bias=True)
#   )
#   (dec): Decoder(
#     (FC2): Linear(in_features=1024, out_features=6400, bias=True)
#     (dec1): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(3, 3))
#     (dec2): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(3, 3))
#     (dec3): ConvTranspose2d(64, 1, kernel_size=(3, 3), stride=(3, 3))
#     (unpool): MaxUnpool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
#   )
# )

# %%
train_loader = DataLoader(Data,batch_size=1)

# %%
loss_func = nn.MSELoss()
optimizer = optim.Adam(net.parameters(), lr=0.0001)

# %%
from tqdm.notebook import tqdm
n_epochs = 100

if torch.cuda.is_available():
    net.cuda()
total_loss = []

epoch_loss = 0
net.train()
for epoch in tqdm(range(n_epochs)):
    print("current epoch is:",epoch)
    epoch_loss = 0
    for x in train_loader:
        mse_loss = 0
        if torch.cuda.is_available():
            x = x.cuda()
            #print(x.shape)
        optimizer.zero_grad()
        prediction = net(x)
        mse_loss = loss_func(prediction, x) # <-- note that i'm using the input as the target
        epoch_loss = epoch_loss + mse_loss.item()
        mse_loss.backward()
        optimizer.step()
        
    #clear_output(wait=True)
    total_loss.append(epoch_loss)
    print('Loss Per epoch: ',epoch_loss)

import matplotlib.pyplot as plt
plt.plot(total_loss)
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# current epoch is: 0
# Loss Per epoch:  2.5898994393646717
# current epoch is: 1
# Loss Per epoch:  2.4544635647907853
# current epoch is: 2
# Loss Per epoch:  2.3587540928274393
# current epoch is: 3
# Loss Per epoch:  2.297836528159678
# current epoch is: 4
# Loss Per epoch:  2.241838009096682
# current epoch is: 5
# Loss Per epoch:  2.1782527025789022
# current epoch is: 6
# Loss Per epoch:  2.1154533098451793
# current epoch is: 7
# Loss Per epoch:  2.054132646881044
# current epoch is: 8
# Loss Per epoch:  1.99213434336707
# current epoch is: 9
# Loss Per epoch:  1.9244609354063869
# current epoch is: 10
# Loss Per epoch:  1.856656040996313
# current epoch is: 11
# Loss Per epoch:  1.8023438677191734
# current epoch is: 12
# Loss Per epoch:  1.7564691370353103
# current epoch is: 13
# Loss Per epoch:  1.717881585471332
# current epoch is: 14
# Loss Per epoch:  1.685778631363064
# current epoch is: 15
# Loss Per epoch:  1.6609338843263686
# current epoch is: 16
# Loss Per epoch:  1.640634489711374
# current epoch is: 17
# Loss Per epoch:  1.6235458510927856
# current epoch is: 18
# Loss Per epoch:  1.6072525805793703
# current epoch is: 19
# Loss Per epoch:  1.5929553881287575
# current epoch is: 20
# Loss Per epoch:  1.579591151792556
# current epoch is: 21
# Loss Per epoch:  1.5669224527664483
# current epoch is: 22
# Loss Per epoch:  1.5561512666754425
# current epoch is: 23
# Loss Per epoch:  1.5404683398082852
# current epoch is: 24
# Loss Per epoch:  1.5249080820940435
# current epoch is: 25
# Loss Per epoch:  1.5113579453900456
# current epoch is: 26
# Loss Per epoch:  1.4990840135142207
# current epoch is: 27
# Loss Per epoch:  1.4875651891343296
# current epoch is: 28
# Loss Per epoch:  1.478674569632858
# current epoch is: 29
# Loss Per epoch:  1.4714569384232163
# current epoch is: 30
# Loss Per epoch:  1.46496897097677
# current epoch is: 31
# Loss Per epoch:  1.4579382706433535
# current epoch is: 32
# Loss Per epoch:  1.4494625204242766
# current epoch is: 33
# Loss Per epoch:  1.4510182114318013
# current epoch is: 34
# Loss Per epoch:  1.4515456245280802
# current epoch is: 35
# Loss Per epoch:  1.4586232122965157
# current epoch is: 36
# Loss Per epoch:  1.4494555247947574
# current epoch is: 37
# Loss Per epoch:  1.4377146898768842
# current epoch is: 38
# Loss Per epoch:  1.4265615232288837
# current epoch is: 39
# Loss Per epoch:  1.4124533543363214
# current epoch is: 40
# Loss Per epoch:  1.399906130041927
# current epoch is: 41
# Loss Per epoch:  1.3901285608299077
# current epoch is: 42
# Loss Per epoch:  1.384089236613363
# current epoch is: 43
# Loss Per epoch:  1.3810207433998585
# current epoch is: 44
# Loss Per epoch:  1.3759819460101426
# current epoch is: 45
# Loss Per epoch:  1.3690446796827018
# current epoch is: 46
# Loss Per epoch:  1.3599851136095822
# current epoch is: 47
# Loss Per epoch:  1.3540909118019044
# current epoch is: 48
# Loss Per epoch:  1.3473911043256521
# current epoch is: 49
# Loss Per epoch:  1.3406364941038191
# current epoch is: 50
# Loss Per epoch:  1.3355410657823086
# current epoch is: 51
# Loss Per epoch:  1.3309224657714367
# current epoch is: 52
# Loss Per epoch:  1.3295492585748434
# current epoch is: 53
# Loss Per epoch:  1.3258133553899825
# current epoch is: 54
# Loss Per epoch:  1.323537887306884
# current epoch is: 55
# Loss Per epoch:  1.3273811188992113
# current epoch is: 56
# Loss Per epoch:  1.3199491982813925
# current epoch is: 57
# Loss Per epoch:  1.31138037587516
# current epoch is: 58
# Loss Per epoch:  1.303552165394649
# current epoch is: 59
# Loss Per epoch:  1.2979959787335247
# current epoch is: 60
# Loss Per epoch:  1.2894228547811508
# current epoch is: 61
# Loss Per epoch:  1.2848166769836098
# current epoch is: 62
# Loss Per epoch:  1.2802953496575356
# current epoch is: 63
# Loss Per epoch:  1.276065391022712
# current epoch is: 64
# Loss Per epoch:  1.272070158738643
# current epoch is: 65
# Loss Per epoch:  1.2684369436465204
# current epoch is: 66
# Loss Per epoch:  1.266749664209783
# current epoch is: 67
# Loss Per epoch:  1.2668075105175376
# current epoch is: 68
# Loss Per epoch:  1.2670115006621927
# current epoch is: 69
# Loss Per epoch:  1.2631731829605997
# current epoch is: 70
# Loss Per epoch:  1.2617779735010117
# current epoch is: 71
# Loss Per epoch:  1.2559811654500663
# current epoch is: 72
# Loss Per epoch:  1.248873096657917
# current epoch is: 73
# Loss Per epoch:  1.2443865528330207
# current epoch is: 74
# Loss Per epoch:  1.2385917862411588
# current epoch is: 75
# Loss Per epoch:  1.2364007101859897
# current epoch is: 76
# Loss Per epoch:  1.2339374697767198
# current epoch is: 77
# Loss Per epoch:  1.2320046173408628
# current epoch is: 78
# Loss Per epoch:  1.2318672284018248
# current epoch is: 79
# Loss Per epoch:  1.2297331406734884
# current epoch is: 80
# Loss Per epoch:  1.2282765586860478
# current epoch is: 81
# Loss Per epoch:  1.2269346022512764
# current epoch is: 82
# Loss Per epoch:  1.2243815041147172
# current epoch is: 83
# Loss Per epoch:  1.2224277544301003
# current epoch is: 84
# Loss Per epoch:  1.2202076017856598
# current epoch is: 85
# Loss Per epoch:  1.2155518080107868
# current epoch is: 86
# Loss Per epoch:  1.2142821478191763
# current epoch is: 87
# Loss Per epoch:  1.211897416273132
# current epoch is: 88
# Loss Per epoch:  1.209450488211587
# current epoch is: 89
# Loss Per epoch:  1.21008471515961
# current epoch is: 90
# Loss Per epoch:  1.2089061671867967
# current epoch is: 91
# Loss Per epoch:  1.2078835517168045
# current epoch is: 92
# Loss Per epoch:  1.204147916752845
# current epoch is: 93
# Loss Per epoch:  1.2002340441104025
# current epoch is: 94
# Loss Per epoch:  1.1982996652368456
# current epoch is: 95
# Loss Per epoch:  1.1967702759429812
# current epoch is: 96
# Loss Per epoch:  1.195683115394786
# current epoch is: 97
# Loss Per epoch:  1.196965376380831
# current epoch is: 98
# Loss Per epoch:  1.196871538180858
# current epoch is: 99
# Loss Per epoch:  1.196361648151651

# %%
import matplotlib.pyplot as plt

net.cpu()
net.eval()
counter = 0
for i in range(10):
    counter = counter + 1
    fig,ax = plt.subplots(1,2,figsize=(8,4))
    x = Data[i]
    input_img = x[0]
    #print(input_img)
    model_pred = net(x.unsqueeze(0))[0].cpu().data.numpy()[0]
    #print(model_pred)
    ax[0].set_title('Input SEM Image',fontsize=12)
    ax[1].set_title('Reconstructed SEM Image',fontsize=12)
    ax[0].imshow(input_img,cmap='gray',vmin=0,vmax=1)
    ax[1].imshow(model_pred,cmap='gray',vmin=0,vmax=1)

# %%
net.enc2.weight.shape
# Out:
# ---------------------------------------------------------------------------
# ModuleAttributeError                      Traceback (most recent call last)
# <ipython-input-49-2cc8bfa4b408> in <module>()
# ----> 1 net.enc2.weight.shape
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     770                 return modules[name]
#     771         raise ModuleAttributeError("'{}' object has no attribute '{}'".format(
# --> 772             type(self).__name__, name))
#     773
#     774     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# ModuleAttributeError: 'Conv2d_AutoEncoder' object has no attribute 'enc2'
